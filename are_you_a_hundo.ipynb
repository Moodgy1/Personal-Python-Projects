# %%
age = int(input("How old are you? "))
almostthere = 100 - age

if age == 100:
  print("congratulations you are 100 years old")
else:
  print(f"you are {almostthere} years from a 100 years old")
# Out:
# you are 86 years from a 100 years old
