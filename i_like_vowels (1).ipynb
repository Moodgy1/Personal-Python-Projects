# %%
vowels = "aeiouAEIOU"
vowelchecker = input()

for char in vowelchecker:
    if char in vowels:
        global vheybro:
          vowelchecker.replace(char, "")

new_var = print(vheybro)
  # Output: ""
